# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
sales=pd.read_csv("C:/Users/KAYCEE/Downloads/supermarket_sales.csv")
sales.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
sales['date']=pd.to_datetime(sales['date'])
sales['time']=pd.to_datetime(sales['time'])
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   invoice_id               1000 non-null   object
#  1   branch                   1000 non-null   object
#  2   city                     1000 non-null   object
#  3   customer_type            1000 non-null   object
#  4   gender                   1000 non-null   object
#  5   product_line             1000 non-null   object
#  6   unit_price               1000 non-null   float64
#  7   quantity                 1000 non-null   int64
#  8   tax_5%                   1000 non-null   float64
#  9   total                    1000 non-null   float64
#  10  date                     1000 non-null   datetime64[ns]
#  11  time                     1000 non-null   datetime64[ns]
#  12  payment                  1000 non-null   object
# ...

# %%
sales.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
sales.columns=['invoice_id', 'branch', 'city', 'customer_type', 'gender',
       'product_line', 'unit_price', 'quantity', 'tax_5%', 'total', 'date',
       'time', 'payment', 'cogs', 'gross_margin_percentage', 'gross_income',
       'rating']
sales.head()
# Out:
#     invoice_id branch       city customer_type  gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              product_line  unit_price  quantity   tax_5%     total       date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     time      payment    cogs  gross_margin_percentage  gross_income  rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
sales['day_of_the_week'] = sales['date'].dt.day_name()
sales.head()
# Out:
#     invoice_id branch       city customer_type  gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              product_line  unit_price  quantity   tax_5%     total       date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#        payment    cogs  gross_margin_percentage  gross_income  rating  \
# 0      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
#i dropped the time column as i won't be using it for this analysis
sales.drop(columns={'time'},inplace=True)
sales.head()
# Out:
#     invoice_id branch       city customer_type  gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              product_line  unit_price  quantity   tax_5%     total       date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#        payment    cogs  gross_margin_percentage  gross_income  rating  \
# 0      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
print(f'The average cost of goods sold is {sales['cogs'].mean().round(2)}')
print(f"Total revenue : ${sales["total"].sum().round(2)}")
# Out:
# The average cost of goods sold is 307.59
# Total revenue : $322966.75

# %%
#this is count of purchases by gender
sns.countplot(sales['gender'])
plt.xlabel('Count')
plt.ylabel('Gender')
plt.title('Count by Gender')
plt.show()

# %%
#i want to know which method of payment is more usde than the others
sns.countplot(sales['payment'])
plt.xlabel('Count')
plt.ylabel('Method of Payment')
plt.title('Payment Method by Count')
plt.show()

# %%
#i want to know which city has the most sales  by count
sns.countplot(sales['city'])
plt.xlabel('Count')
plt.ylabel('City')
plt.title('Sales Count by City')
plt.show()

# %%
# i want to know which product line sells the most
sns.barplot(x='product_line',y='total',data=sales,estimator=np.sum)
plt.xticks(rotation=50)
plt.ylabel('Total')
plt.xlabel('Product Line')
plt.title('Total Purchases by Product Line')
plt.show()

# %%
# i want to know the count of customer type, to help give me more insights when i would want to know which customer types buys the most product 
sns.countplot(x='customer_type',data=sales)
plt.xlabel('Customer type')
plt.ylabel('Count')
plt.title('Customer Type by Count')
plt.show()

# %%
#i want to know which product line each gender buys 
plt.figure(figsize=(10, 6))
sns.countplot(x='product_line', hue='gender', data=sales)
plt.xticks(rotation=50)  
plt.title('Product Line Purchases by Gender')
plt.xlabel('Product line')
plt.ylabel('Count')
plt.legend(title='Gender')
plt.show()

# %%
#i want to know the average rating for each branch/city
sns.barplot(x='branch',y='rating',data=sales)
plt.xlabel('Branch')
plt.ylabel('Rating')
plt.title('Average Ratings by Branch')
plt.show()

# %%
#i want to find out which day experiences the most sales (by summing up total sale for each day)
sales_per_day = sales.groupby('day_of_the_week')['total'].sum().reset_index()
sns.barplot(x='day_of_the_week', y='total', data=sales_per_day,order=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
plt.title('Total Sales Revenue Per Day')
plt.xlabel('Day')
plt.ylabel('Total Sales')
plt.show()

# %%
#to know which customer type buys our products the most
sns.barplot(x='customer_type',y='total',data=sales,estimator=np.sum)
plt.title('Customer Type by Total Sales')
plt.xlabel('Total')
plt.ylabel('Customer Type')
plt.show()

# %%
#is there a corrolation between unit price and quantity
correlation = sales['unit_price'].corr(sales['quantity'])
print(f"Correlation: {correlation} suggests that there is no corrolation between unit price and quantity.")
# Out:
# Correlation: 0.010777564342497298 suggests that there is no corrolation between unit price and quantity.
